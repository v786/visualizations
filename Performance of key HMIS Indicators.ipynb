# %%
import json
from pprint import pprint

with open('data') as f:
    data = json.load(f)
    
#here we are importing the data that was in json 
#data source :- https://data.gov.in/catalog/performance-key-hmis-indicators-upto-district-level-other-indicators
pprint(data)
# Out:
# [['S.No.',
#   'Indicators',
#   '% Adult Female Inpatients to Total Adult Inpatient - 2011-12',
#   '% Adult Female Inpatients to Total Adult Inpatient - 2010-11',
#   '% Children Inpatient to Total Inpatient - 2011-12',
#   '% Children Inpatient to Total Inpatient - 2010-11',
#   '% Female Inpatient Deaths to Total Inpatient Deaths - 2011-12',
#   '% Female Inpatient Deaths to Total Inpatient Deaths - 2010-11',
#   '% Inpatient Deaths to Total IPD - 2011-12',
#   '% Inpatient Deaths to Total IPD - 2010-11',
#   'IPD (Number) - 2011-12',
#   'IPD (Number) - 2010-11',
#   'OPD (Number) - 2011-12',
#   'OPD (Number) - 2010-11',
#   '% IPD to OPD - 2011-12',
#   '% IPD to OPD - 2010-11',
#   'Number of Major Operations - 2011-12',
#   'Number of Major Operations - 2010-11',
#   'Number of Minor Operations - 2011-12',
#   'Number of Minor Operations - 2010-11',
#   '% Major Operations to Total Operation - 2011-12',
#   '% Major Operations to Total Operation - 2010-11',
# ...

# %%
# Import the necessary packages and modules
import matplotlib.pyplot as plt
import numpy as np
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-5-caf65c30cdd2> in <module>()
#       1 # Import the necessary packages and modules
# ----> 2 import matplotlib.pyplot as plt
#       3 import numpy as np
#
# ModuleNotFoundError: No module named 'matplotlib'
